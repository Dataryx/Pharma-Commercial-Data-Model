# %% [markdown]
# # PCDM Demo Notebook
# Answers the six analyst questions against `warehouse/pcdm.duckdb` after `python -m pcdm all --scale demo`.

# %%
import duckdb
from pathlib import Path
con = duckdb.connect(str(Path('warehouse/pcdm.duckdb')), read_only=True)
print(con.execute('select * from gold.mart_brand_performance_weekly limit 5').df())
print(con.execute('select * from gold.mart_specialty_funnel').df())
print(con.execute('select * from gold.mart_alignment_restatement_impact limit 10').df())
print(con.execute('select * from mdm.match_evaluation').df())
